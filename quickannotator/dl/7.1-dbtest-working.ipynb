# %%
import random
import threading
import time
from sqlalchemy import create_engine, Column, Integer, String, DateTime, func
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy.exc import NoResultFound

# %%
#---- this seems to work!
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from contextlib import contextmanager

from sqlalchemy import create_engine, Column, Integer, String, Boolean, DateTime
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy.exc import NoResultFound
from sqlalchemy.sql import text

# --- Setup the SQLite database & SQLAlchemy ORM ---

# Using a file-based SQLite database and allow multithreaded access:
#engine = create_engine("sqlite:///test9.db", connect_args={"check_same_thread": False})
engine = create_engine('postgresql://postgres@localhost:5333/test_tile')
SessionLocal = sessionmaker(bind=engine)

Base = declarative_base()

class Tile(Base):
    __tablename__ = 'tiles'
    id = Column(Integer, primary_key=True)
    annotation_class_id = Column(Integer, default=1)  # for demo, all tiles use 1
    hasgt = Column(Boolean, default=True)
    datetime = Column(DateTime, default=datetime.datetime.utcnow)
    status = Column(String, default="pending")  # can be "pending", "in_progress", etc.
    worker_id = Column(Integer, nullable=True)    # which worker claimed it

# Drop and recreate the table (for demo purposes)
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)

# %%
# --- Populate the database with some tiles ---
with SessionLocal() as session:
    tiles = []
    for i in range(10):  # create 50 tiles
        tile = Tile(
            annotation_class_id=1,
            hasgt=True,
            # Newer tiles have a more recent datetime:
            datetime=datetime.datetime.utcnow() - datetime.timedelta(seconds=i)
        )
        tiles.append(tile)
    session.add_all(tiles)
    session.commit()

# %%
# --- Utility to get a session ---
@contextmanager
def get_session():
    session = SessionLocal()
    try:
        yield session
        session.commit()
    except Exception as e:
        session.rollback()
        raise e
    finally:
        session.close()

# %%
# -- works with sqlite but not postgis

# # --- The tile-claiming function ---
# def getWorkersTile(worker_id):
#     """
#     Atomically retrieves and marks a tile as 'in_progress' so no two workers claim the same tile.
    
#     Since SQLite does not support row-level locking (FOR UPDATE SKIP LOCKED), we use an atomic update query.
#     """
#     with get_session() as db_session:
#         # Atomically select and update a tile in one query
#         tile = db_session.execute(
#             text("""
#                 UPDATE tiles 
#                 SET status = 'in_progress', worker_id = :worker_id 
#                 WHERE id = (
#                     SELECT id FROM tiles 
#                     WHERE annotation_class_id = 1 
#                     AND hasgt = True 
#                     AND status = 'pending' 
#                     ORDER BY datetime DESC 
#                     LIMIT 1
#                 )
#                 RETURNING id, annotation_class_id, hasgt, datetime, status, worker_id
#             """),
#             {"worker_id": worker_id}
#         ).fetchone()

#         if tile:
#             return f"Worker {worker_id} claimed Tile {tile[0]}"
#         else:
#             return f"Worker {worker_id} found no tile"

# %%
# #--- works postgis
# # --- The tile-claiming function ---
# def getWorkersTile(worker_id):
#     """
#     Atomically retrieves and marks a tile as 'in_progress' so no two workers claim the same tile.
    
#     In PostgreSQL, we use `FOR UPDATE SKIP LOCKED` to ensure that a tile is locked and
#     unavailable for other workers until the current worker commits the transaction.
#     """
#     with get_session() as db_session:
#         # Atomically select and update a tile in one query
#         tile = db_session.execute(
#             text("""
#                 WITH selected_tile AS (
#                     SELECT id FROM tiles 
#                     WHERE annotation_class_id = 1 
#                     AND hasgt = True 
#                     AND status = 'pending'
#                     ORDER BY datetime DESC 
#                     LIMIT 1 
#                     FOR UPDATE SKIP LOCKED
#                 )
#                 UPDATE tiles 
#                 SET status = 'in_progress', worker_id = :worker_id 
#                 WHERE id = (SELECT id FROM selected_tile)
#                 RETURNING id, annotation_class_id, hasgt, datetime, status, worker_id
#             """),
#             {"worker_id": worker_id}
#         ).fetchone()

#         if tile:
#             return f"Worker {worker_id} claimed Tile {tile[0]}"
#         else:
#             return f"Worker {worker_id} found no tile"

# %%
#--- doesn't work sqlite - works postgis
from sqlalchemy.orm import aliased
from sqlalchemy import func

# --- The tile-claiming function ---
def getWorkersTile(worker_id):
    """
    Atomically retrieves and marks a tile as 'in_progress' so no two workers claim the same tile.
    
    This version uses SQLAlchemy ORM with row-level locking to ensure atomicity.
    """
    with get_session() as db_session:
        # Get the Tile class and the query for the tile we're interested in
        tile_query = db_session.query(Tile).filter(
            Tile.annotation_class_id == 1,
            Tile.hasgt == True,
            Tile.status == 'pending'
        ).order_by(Tile.datetime.desc())

        # Lock the selected tile for the current transaction and ensure no other worker can claim it
        tile_query = tile_query.with_for_update(skip_locked=True)

        # Select the first tile
        tile = tile_query.first()

        if tile:
            # Update the selected tile's status and worker_id
            tile.status = 'in_progress'
            tile.worker_id = worker_id
            db_session.commit()

            return f"Worker {worker_id} claimed Tile {tile.id}"
        else:
            return f"Worker {worker_id} found no tile"

# %%
# --- Worker function ---
def worker_function(worker_id):
    result = getWorkersTile(worker_id)
    print(result)
    return result

# %%
# --- Main function: spawn many workers concurrently ---
def main():
    num_workers = 200  # simulate an aggressive scenario with 200 concurrent workers
    results = []
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = [executor.submit(worker_function, worker_id) for worker_id in range(num_workers)]
        for future in as_completed(futures):
            results.append(future.result())
    
    print("\nSummary:")
    claimed = [r for r in results if "claimed Tile" in r]
    for res in results:
        print(res)
    print(f"\nTotal claimed tiles: {len(claimed)}")

if __name__ == "__main__":
    main()
# Out:
# Worker 0 claimed Tile 1
# Worker 2 claimed Tile 3
# Worker 4 claimed Tile 7
# Worker 5 claimed Tile 5
# Worker 3 claimed Tile 2
# Worker 9 claimed Tile 6
# Worker 11 found no tile
# Worker 10 found no tile
# Worker 6 claimed Tile 9
# Worker 15 found no tile
# Worker 14 found no tile
# Worker 1 claimed Tile 4
# Worker 12 found no tile
# Worker 16 found no tile
# Worker 7 claimed Tile 10
# Worker 17 found no tile
# Worker 13 found no tile
# Worker 8 claimed Tile 8
# Worker 19 found no tile
# Worker 22 found no tile
# Worker 24 found no tile
# Worker 26 found no tile
# Worker 20 found no tile
# Worker 18 found no tile
# Worker 23 found no tile
# Worker 29 found no tile
# Worker 21 found no tile
# Worker 31 found no tile
# Worker 28 found no tile
# Worker 35 found no tile
# Worker 30 found no tile
# Worker 25 found no tile
# Worker 33 found no tile
# Worker 27 found no tile
# Worker 40 found no tile
# Worker 39 found no tile
# Worker 41 found no tile
# Worker 37 found no tile
# Worker 34 found no tile
# Worker 44 found no tile
# Worker 36 found no tileWorker 38 found no tile
# Worker 47 found no tile
# Worker 46 found no tile
# Worker 32 found no tile
#
# Worker 42 found no tile
# Worker 55 found no tile
# Worker 52 found no tile
# Worker 48 found no tile
# Worker 43 found no tile
# Worker 57 found no tile
# Worker 45 found no tile
# Worker 51 found no tile
# Worker 50 found no tile
# Worker 59 found no tile
# Worker 49 found no tile
# Worker 60 found no tile
# Worker 58 found no tile
# Worker 56 found no tile
# Worker 54 found no tile
# Worker 61 found no tile
# Worker 53 found no tile
# Worker 63 found no tile
# Worker 62 found no tile
# Worker 66 found no tile
# Worker 65 found no tile
# Worker 64 found no tile
# Worker 68 found no tile
# Worker 67 found no tile
# Worker 69 found no tile
# Worker 72 found no tile
# Worker 71 found no tile
# Worker 75 found no tile
# Worker 77 found no tile
# Worker 79 found no tile
# Worker 70 found no tile
# Worker 74 found no tile
# Worker 80 found no tile
# Worker 84 found no tile
# Worker 76 found no tile
# Worker 73 found no tile
# Worker 81 found no tile
# Worker 88 found no tile
# Worker 85 found no tile
# Worker 78 found no tile
# Worker 86 found no tile
# Worker 98 found no tile
# Worker 89 found no tile
# Worker 91 found no tile
# Worker 93 found no tile
# Worker 83 found no tile
# Worker 103 found no tile
# Worker 96 found no tile
# Worker 102 found no tile
# Worker 92 found no tile
# Worker 82 found no tile
# Worker 109 found no tile
# Worker 101 found no tile
# Worker 108 found no tile
# Worker 87 found no tile
# Worker 107 found no tile
# Worker 90 found no tile
# Worker 111 found no tile
# Worker 114 found no tile
# Worker 110 found no tile
# Worker 105 found no tileWorker 113 found no tile
# Worker 118 found no tile
# Worker 99 found no tile
#
# Worker 112 found no tile
# Worker 116 found no tile
# Worker 115 found no tile
# Worker 119 found no tile
# Worker 125 found no tile
# Worker 95 found no tile
# Worker 123 found no tile
# Worker 121 found no tile
# Worker 127 found no tile
# Worker 120 found no tile
# Worker 135 found no tile
# Worker 117 found no tile
# Worker 104 found no tile
# Worker 126 found no tile
# Worker 97 found no tile
# Worker 131 found no tile
# Worker 129 found no tile
# Worker 136 found no tile
# Worker 147 found no tile
# Worker 94 found no tile
# Worker 146 found no tile
# Worker 138 found no tile
# Worker 144 found no tile
# Worker 143 found no tile
# Worker 134 found no tile
# Worker 140 found no tile
# Worker 148 found no tile
# Worker 142 found no tile
# Worker 137 found no tile
# Worker 141 found no tile
# Worker 130 found no tile
# Worker 149 found no tile
# Worker 139 found no tile
# Worker 122 found no tile
# Worker 132 found no tile
# Worker 145 found no tile
# Worker 133 found no tile
# Worker 155 found no tile
# Worker 100 found no tile
# Worker 157 found no tile
# Worker 151 found no tile
# Worker 152 found no tile
# Worker 160 found no tile
# Worker 168 found no tile
# Worker 156 found no tile
# Worker 158 found no tile
# Worker 172 found no tile
# Worker 170 found no tile
# Worker 128 found no tile
# Worker 164 found no tile
# Worker 106 found no tile
# Worker 171 found no tile
# Worker 178 found no tile
# Worker 163 found no tile
# Worker 185 found no tile
# Worker 169 found no tile
# Worker 174 found no tile
# Worker 183 found no tile
# Worker 179 found no tile
# Worker 184 found no tile
# Worker 188 found no tile
# Worker 189 found no tile
# Worker 181 found no tile
# Worker 191 found no tile
# Worker 186 found no tile
# Worker 154 found no tile
# Worker 176 found no tile
# Worker 194 found no tile
# Worker 192 found no tile
# Worker 180 found no tile
# Worker 182 found no tile
# Worker 198 found no tile
# Worker 166 found no tile
# Worker 199 found no tile
# Worker 196 found no tile
# Worker 159 found no tile
# Worker 195 found no tile
# Worker 167 found no tile
# Worker 193 found no tile
# Worker 175 found no tile
# Worker 153 found no tile
# Worker 124 found no tile
# Worker 173 found no tile
# Worker 197 found no tile
# Worker 150 found no tile
# Worker 177 found no tile
# Worker 190 found no tile
# Worker 165 found no tile
# Worker 161 found no tile
# Worker 187 found no tile
# Worker 162 found no tile
#
# Summary:
# Worker 102 found no tile
# Worker 66 found no tile
# Worker 29 found no tile
# Worker 90 found no tile
# Worker 41 found no tile
# Worker 142 found no tile
# Worker 89 found no tile
# Worker 78 found no tile
# Worker 59 found no tile
# Worker 76 found no tile
# Worker 125 found no tile
# Worker 19 found no tile
# Worker 104 found no tile
# Worker 117 found no tile
# Worker 50 found no tile
# Worker 99 found no tile
# Worker 38 found no tile
# Worker 98 found no tile
# Worker 82 found no tile
# Worker 141 found no tile
# Worker 88 found no tile
# Worker 7 claimed Tile 10
# Worker 133 found no tile
# Worker 86 found no tile
# Worker 137 found no tile
# Worker 105 found no tile
# Worker 75 found no tile
# Worker 31 found no tile
# Worker 138 found no tile
# Worker 47 found no tile
# Worker 106 found no tile
# Worker 140 found no tile
# Worker 46 found no tile
# Worker 48 found no tile
# Worker 83 found no tile
# Worker 111 found no tile
# Worker 134 found no tile
# Worker 43 found no tile
# Worker 135 found no tile
# Worker 52 found no tile
# Worker 136 found no tile
# Worker 172 found no tile
# Worker 160 found no tile
# Worker 91 found no tile
# Worker 74 found no tile
# Worker 40 found no tile
# Worker 30 found no tile
# Worker 26 found no tile
# Worker 149 found no tile
# Worker 64 found no tile
# Worker 158 found no tile
# Worker 79 found no tile
# Worker 152 found no tile
# Worker 155 found no tile
# Worker 123 found no tile
# Worker 0 claimed Tile 1
# Worker 22 found no tile
# Worker 131 found no tile
# Worker 112 found no tile
# Worker 39 found no tile
# Worker 15 found no tile
# Worker 25 found no tile
# Worker 73 found no tile
# Worker 1 claimed Tile 4
# Worker 68 found no tile
# Worker 28 found no tile
# Worker 97 found no tile
# Worker 57 found no tile
# Worker 119 found no tile
# Worker 61 found no tile
# Worker 110 found no tile
# Worker 151 found no tile
# Worker 96 found no tile
# Worker 65 found no tile
# Worker 170 found no tile
# Worker 49 found no tile
# Worker 168 found no tile
# Worker 157 found no tile
# Worker 128 found no tile
# Worker 42 found no tile
# Worker 147 found no tile
# Worker 27 found no tile
# Worker 32 found no tile
# Worker 62 found no tile
# Worker 45 found no tile
# Worker 37 found no tile
# Worker 13 found no tile
# Worker 94 found no tile
# Worker 84 found no tile
# Worker 118 found no tile
# Worker 145 found no tile
# Worker 23 found no tile
# Worker 55 found no tile
# Worker 60 found no tile
# Worker 2 claimed Tile 3
# Worker 178 found no tile
# Worker 107 found no tile
# Worker 108 found no tile
# Worker 72 found no tile
# Worker 16 found no tile
# Worker 3 claimed Tile 2
# Worker 54 found no tile
# Worker 126 found no tile
# Worker 122 found no tile
# Worker 93 found no tile
# Worker 34 found no tile
# Worker 9 claimed Tile 6
# Worker 171 found no tile
# Worker 156 found no tile
# Worker 127 found no tile
# Worker 70 found no tile
# Worker 100 found no tile
# Worker 164 found no tile
# Worker 146 found no tile
# Worker 113 found no tile
# Worker 87 found no tile
# Worker 56 found no tile
# Worker 24 found no tile
# Worker 63 found no tile
# Worker 14 found no tile
# Worker 36 found no tile
# Worker 44 found no tile
# Worker 121 found no tile
# Worker 80 found no tile
# Worker 12 found no tile
# Worker 21 found no tile
# Worker 11 found no tile
# Worker 77 found no tile
# Worker 51 found no tile
# Worker 81 found no tile
# Worker 10 found no tile
# Worker 114 found no tile
# Worker 67 found no tile
# Worker 35 found no tile
# Worker 115 found no tile
# Worker 6 claimed Tile 9
# Worker 120 found no tile
# Worker 144 found no tile
# Worker 143 found no tile
# Worker 139 found no tile
# Worker 85 found no tile
# Worker 5 claimed Tile 5
# Worker 17 found no tile
# Worker 132 found no tile
# Worker 129 found no tile
# Worker 53 found no tile
# Worker 69 found no tile
# Worker 130 found no tile
# Worker 92 found no tile
# Worker 58 found no tile
# Worker 20 found no tile
# Worker 95 found no tile
# Worker 116 found no tile
# Worker 18 found no tile
# Worker 109 found no tile
# Worker 4 claimed Tile 7
# Worker 148 found no tile
# Worker 8 claimed Tile 8
# Worker 101 found no tile
# Worker 33 found no tile
# Worker 71 found no tile
# Worker 103 found no tile
# Worker 163 found no tile
# Worker 185 found no tile
# Worker 169 found no tile
# Worker 174 found no tile
# Worker 183 found no tile
# Worker 179 found no tile
# Worker 184 found no tile
# Worker 188 found no tile
# Worker 189 found no tile
# Worker 181 found no tile
# Worker 191 found no tile
# Worker 186 found no tile
# Worker 154 found no tile
# Worker 176 found no tile
# Worker 194 found no tile
# Worker 192 found no tile
# Worker 180 found no tile
# Worker 182 found no tile
# Worker 198 found no tile
# Worker 166 found no tile
# Worker 199 found no tile
# Worker 196 found no tile
# Worker 159 found no tile
# Worker 195 found no tile
# Worker 167 found no tile
# Worker 193 found no tile
# Worker 175 found no tile
# Worker 153 found no tile
# Worker 124 found no tile
# Worker 173 found no tile
# Worker 197 found no tile
# Worker 150 found no tile
# Worker 177 found no tile
# Worker 190 found no tile
# Worker 165 found no tile
# Worker 161 found no tile
# Worker 187 found no tile
# Worker 162 found no tile
#
# Total claimed tiles: 10
