# %%
import random
import threading
import time
from sqlalchemy import create_engine, Column, Integer, String, DateTime, func
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy.exc import NoResultFound

# %%
#---- this seems to work!
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from contextlib import contextmanager

from sqlalchemy import create_engine, Column, Integer, String, Boolean, DateTime
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy.exc import NoResultFound
from sqlalchemy.sql import text

from sqlalchemy import Index


# --- Setup the SQLite database & SQLAlchemy ORM ---

# Using a file-based SQLite database and allow multithreaded access:
#engine = create_engine("sqlite:///test0.db", connect_args={"check_same_thread": False})
engine = create_engine('postgresql://postgres@localhost:5333/ajtest1')
SessionLocal = sessionmaker(bind=engine)

Base = declarative_base()

class Tile(Base):
    __tablename__ = 'tiles'
    id = Column(Integer, primary_key=True)
    annotation_class_id = Column(Integer, default=1)  # for demo, all tiles use 1
    hasgt = Column(Boolean, default=True)
    datetime = Column(DateTime, default=datetime.datetime.utcnow)
    status = Column(String, default="pending")  # can be "pending", "in_progress", etc.
    worker_id = Column(Integer, nullable=True)    # which worker claimed it

    # Correct way to define indexes
    __table_args__ = (
        Index("idx_datetime", datetime),
        Index("idx_status", status),
    )
# Drop and recreate the table (for demo purposes)
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)

# %%
Tile.__table__.indexes
# Out:
# {Index('idx_datetime', Column('datetime', DateTime(), table=<tiles>, default=CallableColumnDefault(<function datetime.utcnow at 0x7f8eb6acfeb0>))),
#  Index('idx_status', Column('status', String(), table=<tiles>, default=ScalarElementColumnDefault('pending')))}

# %%
# --- Populate the database with some tiles ---
with SessionLocal() as session:
    tiles = []
    for i in range(100_000):  # create tiles
        tile = Tile(
            annotation_class_id=1,
            hasgt=True,
            # Newer tiles have a more recent datetime:
            datetime=datetime.datetime.utcnow() - datetime.timedelta(seconds=i)
        )
        tiles.append(tile)
    session.add_all(tiles)
    session.commit()

# %%
# --- Utility to get a session ---
@contextmanager
def get_session():
    session = SessionLocal()
    try:
        yield session
        session.commit()
    except Exception as e:
        session.rollback()
        raise e
    finally:
        session.close()

# %%
from sqlalchemy.orm import Session
from sqlalchemy import update, select, text
from sqlalchemy.engine import Engine

def getWorkersTile(worker_id: int):
    """
    Atomically retrieves and marks a tile as 'in_progress' so no two workers claim the same tile.
    """
    with get_session() as db_session:  # Ensure this provides a session context
        dialect = db_session.bind.dialect.name  # Get database type
        with db_session.begin():  # Explicit transaction
            subquery = (
                select(Tile.id)
                .where(Tile.annotation_class_id == 1,
                       Tile.hasgt == True,
                       Tile.status == 'pending')
                .order_by(Tile.datetime.desc())
                .limit(1).with_for_update(skip_locked=True)
            )
            
            tile_id = db_session.execute(
                update(Tile)
                .where(Tile.id == subquery.scalar_subquery())
                .where(Tile.status == 'pending')  # Ensures another worker hasn't claimed it
                .values(status='in_progress', worker_id=worker_id)
                .returning(Tile.id)
            ).scalar()
            
            if tile:
                return f"Worker {worker_id} claimed Tile {tile_id}"
            else:
                return f"Worker {worker_id} found no tile"

# %%
# --- Worker function ---
def worker_function(worker_id):
    result = getWorkersTile(worker_id)
    print(result)
    return result

# %%
# --- Main function: spawn many workers concurrently ---
def main():
    num_workers = 200  # simulate an aggressive scenario with 200 concurrent workers
    results = []
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = [executor.submit(worker_function, worker_id) for worker_id in range(num_workers)]
        for future in as_completed(futures):
            results.append(future.result())
    
    print("\nSummary:")
    claimed = [r for r in results if "claimed Tile" in r]
    for res in results:
        print(res)
    print(f"\nTotal claimed tiles: {len(claimed)}")

if __name__ == "__main__":
    main()
# Out:
# Worker 0 claimed Tile 1
# Worker 1 claimed Tile 2
# Worker 8 claimed Tile 3
# Worker 5 claimed Tile 6
# Worker 3 claimed Tile 5
# Worker 4 claimed Tile 4
# Worker 6 claimed Tile 7
# Worker 9 claimed Tile 8
# Worker 16 claimed Tile 14
# Worker 12 claimed Tile 15
# Worker 7 claimed Tile 11
# Worker 11 claimed Tile 10
# Worker 15 claimed Tile 13
# Worker 10 claimed Tile 12
# Worker 22 claimed Tile 22
# Worker 2 claimed Tile 9
# Worker 13 claimed Tile 16
# Worker 18 claimed Tile 19
# Worker 20 claimed Tile 20
# Worker 14 claimed Tile 24
# Worker 21 claimed Tile 21
# Worker 24 claimed Tile 23
# Worker 30 claimed Tile 29
# Worker 25 claimed Tile 25
# Worker 23 claimed Tile 28
# Worker 27 claimed Tile 27
# Worker 17 claimed Tile 18
# Worker 26 claimed Tile 26
# Worker 28 claimed Tile 34
# Worker 32 claimed Tile 30
# Worker 35 claimed Tile 36
# Worker 19 claimed Tile 17
# Worker 33 claimed Tile 31
# Worker 29 claimed Tile 32
# Worker 31 claimed Tile 33
# Worker 36 claimed Tile 43
# Worker 44 claimed Tile 40
# Worker 34 claimed Tile 35
# Worker 47 claimed Tile 41
# Worker 43 claimed Tile 42
# Worker 40 claimed Tile 46
# Worker 49 claimed Tile 45
# Worker 45 claimed Tile 47
# Worker 38 claimed Tile 37
# Worker 37 claimed Tile 44
# Worker 41 claimed Tile 38
# Worker 42 claimed Tile 39
# Worker 51 claimed Tile 49
# Worker 59 claimed Tile 52
# Worker 60 claimed Tile 53
# Worker 58 claimed Tile 51
# Worker 50 claimed Tile 48
# Worker 62 claimed Tile 54
# Worker 68 claimed Tile 59
# Worker 54 claimed Tile 50
# Worker 64 claimed Tile 56
# Worker 63 claimed Tile 55
# Worker 72 claimed Tile 64
# Worker 66 claimed Tile 57
# Worker 39 claimed Tile 62
# Worker 76 claimed Tile 66
# Worker 57 claimed Tile 61
# Worker 71 claimed Tile 63
# Worker 69 claimed Tile 60
# Worker 67 claimed Tile 58
# Worker 74 claimed Tile 65
# Worker 61 claimed Tile 68
# Worker 79 claimed Tile 69
# Worker 84 claimed Tile 74
# Worker 46 claimed Tile 67
# Worker 83 claimed Tile 73
# Worker 56 claimed Tile 75
# Worker 82 claimed Tile 72
# Worker 80 claimed Tile 70
# Worker 87 claimed Tile 81
# Worker 81 claimed Tile 71
# Worker 53 claimed Tile 78
# Worker 75 claimed Tile 76
# Worker 89 claimed Tile 83
# Worker 98 claimed Tile 87
# Worker 95 claimed Tile 86
# Worker 55 claimed Tile 77
# Worker 94 claimed Tile 85
# Worker 86 claimed Tile 79
# Worker 92 claimed Tile 84
# Worker 70 claimed Tile 80
# Worker 100 claimed Tile 89
# Worker 99 claimed Tile 88
# Worker 88 claimed Tile 82
# Worker 111 claimed Tile 94
# Worker 103 claimed Tile 90
# Worker 110 claimed Tile 93
# Worker 106 claimed Tile 91
# Worker 108 claimed Tile 92
# Worker 97 claimed Tile 99
# Worker 127 claimed Tile 106
# Worker 85 claimed Tile 102
# Worker 78 claimed Tile 100
# Worker 123 claimed Tile 103
# Worker 121 claimed Tile 98
# Worker 116 claimed Tile 95
# Worker 122 claimed Tile 101
# Worker 124 claimed Tile 104
# Worker 118 claimed Tile 96
# Worker 128 claimed Tile 107
# Worker 130 claimed Tile 109
# Worker 120 claimed Tile 97
# Worker 129 claimed Tile 108
# Worker 125 claimed Tile 105
# Worker 139 claimed Tile 111
# Worker 115 claimed Tile 117
# Worker 96 claimed Tile 113
# Worker 144 claimed Tile 116
# Worker 140 claimed Tile 112
# Worker 143 claimed Tile 115
# Worker 102 claimed Tile 122
# Worker 77 claimed Tile 119
# Worker 73 claimed Tile 121
# Worker 119 claimed Tile 123
# Worker 136 claimed Tile 110
# Worker 48 claimed Tile 118
# Worker 150 claimed Tile 126
# Worker 142 claimed Tile 114
# Worker 146 claimed Tile 125
# Worker 151 claimed Tile 127
# Worker 155 claimed Tile 128
# Worker 113 claimed Tile 120
# Worker 145 claimed Tile 124
# Worker 161 claimed Tile 132
# Worker 159 claimed Tile 130
# Worker 160 claimed Tile 131
# Worker 162 claimed Tile 133
# Worker 158 claimed Tile 129
# Worker 132 claimed Tile 136
# Worker 167 claimed Tile 140
# Worker 164 claimed Tile 135
# Worker 171 claimed Tile 142
# Worker 52 claimed Tile 137
# Worker 174 claimed Tile 143
# Worker 166 claimed Tile 139
# Worker 163 claimed Tile 134
# Worker 183 claimed Tile 149
# Worker 107 claimed Tile 138
# Worker 178 claimed Tile 145
# Worker 169 claimed Tile 141
# Worker 176 claimed Tile 144
# Worker 189 claimed Tile 153
# Worker 186 claimed Tile 151
# Worker 185 claimed Tile 150
# Worker 179 claimed Tile 146
# Worker 181 claimed Tile 147
# Worker 182 claimed Tile 148
# Worker 195 claimed Tile 156
# Worker 187 claimed Tile 152
# Worker 198 claimed Tile 158
# Worker 194 claimed Tile 155
# Worker 199 claimed Tile 163
# Worker 105 claimed Tile 159
# Worker 133 claimed Tile 162
# Worker 157 claimed Tile 160
# Worker 197 claimed Tile 157
# Worker 91 claimed Tile 166
# Worker 141 claimed Tile 167
# Worker 134 claimed Tile 164
# Worker 138 claimed Tile 165
# Worker 192 claimed Tile 154
# Worker 172 claimed Tile 171
# Worker 109 claimed Tile 161
# Worker 170 claimed Tile 169
# Worker 137 claimed Tile 168
# Worker 101 claimed Tile 173
# Worker 175 claimed Tile 175
# Worker 90 claimed Tile 178
# Worker 112 claimed Tile 172
# Worker 147 claimed Tile 180
# Worker 180 claimed Tile 179
# Worker 148 claimed Tile 181
# Worker 114 claimed Tile 170
# Worker 177 claimed Tile 177
# Worker 173 claimed Tile 176
# Worker 117 claimed Tile 174
# Worker 184 claimed Tile 183
# Worker 104 claimed Tile 182
# Worker 93 claimed Tile 185
# Worker 149 claimed Tile 184
# Worker 152 claimed Tile 187
# Worker 156 claimed Tile 193
# Worker 188 claimed Tile 186
# Worker 196 claimed Tile 192
# Worker 65 claimed Tile 188
# Worker 193 claimed Tile 194
# Worker 191 claimed Tile 189
# Worker 135 claimed Tile 195
# Worker 154 claimed Tile 190
# Worker 190 claimed Tile 191
# Worker 131 claimed Tile 196
# Worker 153 claimed Tile 197
# Worker 126 claimed Tile 198
# Worker 165 claimed Tile 200
# Worker 168 claimed Tile 199
#
# Summary:
# Worker 33 claimed Tile 31
# Worker 166 claimed Tile 139
# Worker 35 claimed Tile 36
# Worker 82 claimed Tile 72
# Worker 50 claimed Tile 48
# Worker 176 claimed Tile 144
# Worker 31 claimed Tile 33
# Worker 11 claimed Tile 10
# Worker 59 claimed Tile 52
# Worker 97 claimed Tile 99
# Worker 84 claimed Tile 74
# Worker 83 claimed Tile 73
# Worker 136 claimed Tile 110
# Worker 125 claimed Tile 105
# Worker 89 claimed Tile 83
# Worker 51 claimed Tile 49
# Worker 40 claimed Tile 46
# Worker 3 claimed Tile 5
# Worker 119 claimed Tile 123
# Worker 145 claimed Tile 124
# Worker 94 claimed Tile 85
# Worker 76 claimed Tile 66
# Worker 123 claimed Tile 103
# Worker 52 claimed Tile 137
# Worker 60 claimed Tile 53
# Worker 171 claimed Tile 142
# Worker 13 claimed Tile 16
# Worker 80 claimed Tile 70
# Worker 53 claimed Tile 78
# Worker 106 claimed Tile 91
# Worker 0 claimed Tile 1
# Worker 6 claimed Tile 7
# Worker 102 claimed Tile 122
# Worker 85 claimed Tile 102
# Worker 122 claimed Tile 101
# Worker 167 claimed Tile 140
# Worker 86 claimed Tile 79
# Worker 54 claimed Tile 50
# Worker 163 claimed Tile 134
# Worker 162 claimed Tile 133
# Worker 56 claimed Tile 75
# Worker 120 claimed Tile 97
# Worker 81 claimed Tile 71
# Worker 21 claimed Tile 21
# Worker 127 claimed Tile 106
# Worker 108 claimed Tile 92
# Worker 20 claimed Tile 20
# Worker 110 claimed Tile 93
# Worker 160 claimed Tile 131
# Worker 139 claimed Tile 111
# Worker 129 claimed Tile 108
# Worker 15 claimed Tile 13
# Worker 63 claimed Tile 55
# Worker 78 claimed Tile 100
# Worker 73 claimed Tile 121
# Worker 68 claimed Tile 59
# Worker 36 claimed Tile 43
# Worker 28 claimed Tile 34
# Worker 67 claimed Tile 58
# Worker 42 claimed Tile 39
# Worker 130 claimed Tile 109
# Worker 189 claimed Tile 153
# Worker 150 claimed Tile 126
# Worker 95 claimed Tile 86
# Worker 34 claimed Tile 35
# Worker 71 claimed Tile 63
# Worker 143 claimed Tile 115
# Worker 41 claimed Tile 38
# Worker 9 claimed Tile 8
# Worker 64 claimed Tile 56
# Worker 47 claimed Tile 41
# Worker 22 claimed Tile 22
# Worker 46 claimed Tile 67
# Worker 161 claimed Tile 132
# Worker 45 claimed Tile 47
# Worker 169 claimed Tile 141
# Worker 159 claimed Tile 130
# Worker 43 claimed Tile 42
# Worker 87 claimed Tile 81
# Worker 61 claimed Tile 68
# Worker 29 claimed Tile 32
# Worker 17 claimed Tile 18
# Worker 142 claimed Tile 114
# Worker 118 claimed Tile 96
# Worker 115 claimed Tile 117
# Worker 39 claimed Tile 62
# Worker 132 claimed Tile 136
# Worker 79 claimed Tile 69
# Worker 69 claimed Tile 60
# Worker 44 claimed Tile 40
# Worker 38 claimed Tile 37
# Worker 75 claimed Tile 76
# Worker 66 claimed Tile 57
# Worker 107 claimed Tile 138
# Worker 37 claimed Tile 44
# Worker 151 claimed Tile 127
# Worker 144 claimed Tile 116
# Worker 70 claimed Tile 80
# Worker 27 claimed Tile 27
# Worker 7 claimed Tile 11
# Worker 158 claimed Tile 129
# Worker 116 claimed Tile 95
# Worker 55 claimed Tile 77
# Worker 49 claimed Tile 45
# Worker 32 claimed Tile 30
# Worker 18 claimed Tile 19
# Worker 5 claimed Tile 6
# Worker 140 claimed Tile 112
# Worker 23 claimed Tile 28
# Worker 16 claimed Tile 14
# Worker 124 claimed Tile 104
# Worker 8 claimed Tile 3
# Worker 88 claimed Tile 82
# Worker 10 claimed Tile 12
# Worker 113 claimed Tile 120
# Worker 100 claimed Tile 89
# Worker 128 claimed Tile 107
# Worker 74 claimed Tile 65
# Worker 2 claimed Tile 9
# Worker 99 claimed Tile 88
# Worker 58 claimed Tile 51
# Worker 96 claimed Tile 113
# Worker 48 claimed Tile 118
# Worker 121 claimed Tile 98
# Worker 146 claimed Tile 125
# Worker 30 claimed Tile 29
# Worker 111 claimed Tile 94
# Worker 103 claimed Tile 90
# Worker 14 claimed Tile 24
# Worker 24 claimed Tile 23
# Worker 178 claimed Tile 145
# Worker 174 claimed Tile 143
# Worker 72 claimed Tile 64
# Worker 1 claimed Tile 2
# Worker 164 claimed Tile 135
# Worker 57 claimed Tile 61
# Worker 98 claimed Tile 87
# Worker 26 claimed Tile 26
# Worker 183 claimed Tile 149
# Worker 77 claimed Tile 119
# Worker 155 claimed Tile 128
# Worker 25 claimed Tile 25
# Worker 4 claimed Tile 4
# Worker 19 claimed Tile 17
# Worker 12 claimed Tile 15
# Worker 92 claimed Tile 84
# Worker 62 claimed Tile 54
# Worker 186 claimed Tile 151
# Worker 185 claimed Tile 150
# Worker 179 claimed Tile 146
# Worker 181 claimed Tile 147
# Worker 182 claimed Tile 148
# Worker 195 claimed Tile 156
# Worker 187 claimed Tile 152
# Worker 198 claimed Tile 158
# Worker 194 claimed Tile 155
# Worker 199 claimed Tile 163
# Worker 105 claimed Tile 159
# Worker 133 claimed Tile 162
# Worker 157 claimed Tile 160
# Worker 197 claimed Tile 157
# Worker 91 claimed Tile 166
# Worker 141 claimed Tile 167
# Worker 134 claimed Tile 164
# Worker 138 claimed Tile 165
# Worker 192 claimed Tile 154
# Worker 172 claimed Tile 171
# Worker 109 claimed Tile 161
# Worker 170 claimed Tile 169
# Worker 137 claimed Tile 168
# Worker 101 claimed Tile 173
# Worker 175 claimed Tile 175
# Worker 90 claimed Tile 178
# Worker 112 claimed Tile 172
# Worker 147 claimed Tile 180
# Worker 180 claimed Tile 179
# Worker 148 claimed Tile 181
# Worker 114 claimed Tile 170
# Worker 177 claimed Tile 177
# Worker 173 claimed Tile 176
# Worker 117 claimed Tile 174
# Worker 184 claimed Tile 183
# Worker 104 claimed Tile 182
# Worker 93 claimed Tile 185
# Worker 149 claimed Tile 184
# Worker 152 claimed Tile 187
# Worker 156 claimed Tile 193
# Worker 188 claimed Tile 186
# Worker 196 claimed Tile 192
# Worker 65 claimed Tile 188
# Worker 193 claimed Tile 194
# Worker 191 claimed Tile 189
# Worker 135 claimed Tile 195
# Worker 154 claimed Tile 190
# Worker 190 claimed Tile 191
# Worker 131 claimed Tile 196
# Worker 153 claimed Tile 197
# Worker 126 claimed Tile 198
# Worker 165 claimed Tile 200
# Worker 168 claimed Tile 199
#
# Total claimed tiles: 200

# %%
# %%timeit
result = getWorkersTile(-1)
# Out:
# 4.11 ms ± 103 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
