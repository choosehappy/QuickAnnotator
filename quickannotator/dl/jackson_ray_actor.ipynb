# %%
# %load_ext autoreload
# %autoreload 2

# %%
#--- should clean imports - copy paste
import ray
from quickannotator.dl.ray_jackson import start_processing, get_processing_actors
# Out:
# /opt/uv_venv/lib/python3.10/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.5' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
ray.init(namespace="quick_annotator")
# Out:
# 2025-03-20 15:59:31,999	WARNING services.py:1996 -- WARNING: The object store is using /tmp instead of /dev/shm because /dev/shm has only 8589930496 bytes available. This will harm performance! You may be able to free up space by deleting files in /dev/shm. If you are inside a Docker container, you can increase /dev/shm size by passing '--shm-size=9.08gb' to 'docker run' (or add it to the run_options list in a Ray cluster config). Make sure to set this to more than 30% of available RAM.
# 2025-03-20 15:59:32,068	INFO worker.py:1752 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.10.0', ray_commit='09abba26b5bf2707639bb637c208d062a47b46f6')
# (DLActor pid=56219) annotation_class_id=3
# (DLActor pid=56219) tile_size=2048
# (DLActor pid=56219) starting up dl_actor_class_3
# (DLActor pid=56219)
# (DLActor pid=56219) View detailed results here: /root/ray_results/TorchTrainer_2025-03-20_15-59-42
# ...

# %%
ray.util.list_named_actors()
# Out:
# []

# %%
class_2_id = 2
class_3_id = 3

# %%
start_processing(class_2_id)

# %%
get_processing_actors()

# %%
start_processing(class_3_id)
# Out:
# InitSpatiaMetaData() error:"table spatial_ref_sys already exists"
# Actor(DLActor, e26e3e5498e697bb85e888d601000000)
# 2025-03-20 15:59:50,020	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::DLActor.start_dlproc() (pid=56219, ip=172.17.0.2, actor_id=e26e3e5498e697bb85e888d601000000, repr=<quickannotator.dl.ray_jackson.DLActor object at 0x7fcaf337b130>)
#   File "/opt/QuickAnnotator/quickannotator/dl/ray_jackson.py", line 69, in start_dlproc
#     self.hexid = trainer.fit().hex() ##widly -- this doesn't save the result in the actor
#   File "/opt/uv_venv/lib/python3.10/site-packages/ray/train/base_trainer.py", line 623, in fit
#     result_grid = tuner.fit()
#   File "/opt/uv_venv/lib/python3.10/site-packages/ray/tune/tuner.py", line 379, in fit
#     return self._local_tuner.fit()
#   File "/opt/uv_venv/lib/python3.10/site-packages/ray/tune/impl/tuner_internal.py", line 483, in fit
#     return ResultGrid(self._experiment_analysis)
# ...

# %%
get_processing_actors()
