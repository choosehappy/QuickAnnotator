# %%
# %load_ext autoreload
# %autoreload 2

# %%
#--- should clean imports - copy paste
import ray
from quickannotator.dl.ray_jackson import start_processing, get_processing_actors
from quickannotator.api.v1.utils.shared_crud import reset_all_PROCESSING_tiles
from quickannotator.db import get_session

# %%
ray.init(address='auto', namespace="quick_annotator")

# %%
ray.util.list_named_actors()

# %%
class_2_id = 2
class_3_id = 3

# %%
start_processing(class_2_id)

# %%
get_processing_actors()

# %%
start_processing(class_3_id)

# %%
get_processing_actors()

# %%
with get_session() as db_session:
    reset_all_PROCESSING_tiles(annotation_class_id=2)
