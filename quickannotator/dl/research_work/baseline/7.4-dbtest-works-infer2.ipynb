# %%
import random
import threading
import time
from sqlalchemy import create_engine, Column, Integer, String, DateTime, func
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy.exc import NoResultFound

# %%
#---- this seems to work!
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from contextlib import contextmanager

from sqlalchemy import create_engine, Column, Integer, String, Boolean, DateTime
from sqlalchemy.orm import sessionmaker, declarative_base
from sqlalchemy.exc import NoResultFound
from sqlalchemy.sql import text

from sqlalchemy import Index


# --- Setup the SQLite database & SQLAlchemy ORM ---

# Using a file-based SQLite database and allow multithreaded access:
engine = create_engine("sqlite:///test2.db", connect_args={"check_same_thread": False})
#engine = create_engine('postgresql://postgres@localhost:5333/ajtest1')
SessionLocal = sessionmaker(bind=engine)

Base = declarative_base()

class Tile(Base):
    __tablename__ = 'tiles'
    id = Column(Integer, primary_key=True)
    annotation_class_id = Column(Integer, default=1)  # for demo, all tiles use 1
    hasgt = Column(Boolean, default=True)
    datetime = Column(DateTime, default=datetime.datetime.utcnow)
    status = Column(String, default="pending")  # can be "pending", "in_progress", etc.
    worker_id = Column(Integer, nullable=True)    # which worker claimed it

    # Correct way to define indexes
    __table_args__ = (
        Index("idx_datetime", datetime),
        Index("idx_status", status),
    )
# Drop and recreate the table (for demo purposes)
Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)

# %%
Tile.__table__.indexes
# Out:
# {Index('idx_datetime', Column('datetime', DateTime(), table=<tiles>, default=CallableColumnDefault(<function datetime.utcnow at 0x7f0de1906050>))),
#  Index('idx_status', Column('status', String(), table=<tiles>, default=ScalarElementColumnDefault('pending')))}

# %%
# --- Populate the database with some tiles ---
with SessionLocal() as session:
    tiles = []
    for i in range(1_000):  # create tiles
        tile = Tile(
            annotation_class_id=1,
            hasgt=True,
            # Newer tiles have a more recent datetime:
            datetime=datetime.datetime.utcnow() - datetime.timedelta(seconds=i)
        )
        tiles.append(tile)
    session.add_all(tiles)
    session.commit()

# %%
# --- Utility to get a session ---
@contextmanager
def get_session():
    session = SessionLocal()
    try:
        yield session
        session.commit()
    except Exception as e:
        session.rollback()
        raise e
    finally:
        session.close()

# %%
from sqlalchemy.orm import Session
from sqlalchemy import update, select, text
from sqlalchemy.engine import Engine

def getWorkersTile(worker_id: int):
    """
    Atomically retrieves and marks a tile as 'in_progress' so no two workers claim the same tile.
    """
    with get_session() as db_session:  # Ensure this provides a session context
        dialect = db_session.bind.dialect.name  # Get database type
        with db_session.begin():  # Explicit transaction
            subquery = (
                select(Tile.id)
                .where(Tile.annotation_class_id == 1,
                       Tile.hasgt == True,
                       Tile.status == 'pending')
                .order_by(Tile.datetime.desc())
                .limit(2).with_for_update(skip_locked=True)
            )
            
            tiles = db_session.execute(
                update(Tile)
                .where(Tile.id.in_(subquery)) #.scalar_subquery())
                .where(Tile.status == 'pending')  # Ensures another worker hasn't claimed it
                .values(status='in_progress', worker_id=worker_id)
                .returning(Tile)
            ).fetchall()
            
            if tiles:
                return f"Worker {worker_id} claimed Tile {tiles[0]["id"]}"
            else:
                return f"Worker {worker_id} found no tile"
# Out:
#   Cell In[9], line 30
#     return f"Worker {worker_id} claimed Tile {tiles[0]["id"]}"
#                                                         ^
# SyntaxError: f-string: unmatched '['

# %%
# --- Worker function ---
def worker_function(worker_id):
    result = getWorkersTile(worker_id)
    print(result)
    return result

# %%
# --- Main function: spawn many workers concurrently ---
def main():
    num_workers = 200  # simulate an aggressive scenario with 200 concurrent workers
    results = []
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = [executor.submit(worker_function, worker_id) for worker_id in range(num_workers)]
        for future in as_completed(futures):
            results.append(future.result())
    
    print("\nSummary:")
    claimed = [r for r in results if "claimed Tile" in r]
    for res in results:
        print(res)
    print(f"\nTotal claimed tiles: {len(claimed)}")

if __name__ == "__main__":
    main()
# Out:
# Worker 0 claimed Tile (<__main__.Tile object at 0x7f0de00c9750>,)
# Worker 15 claimed Tile (<__main__.Tile object at 0x7f0de0391810>,)
# Worker 55 claimed Tile (<__main__.Tile object at 0x7f0de03d3cd0>,)
# Worker 9 claimed Tile (<__main__.Tile object at 0x7f0de00fc5b0>,)
# Worker 18 claimed Tile (<__main__.Tile object at 0x7f0de01dfd60>,)
# Worker 1 claimed Tile (<__main__.Tile object at 0x7f0de02842e0>,)
# Worker 133 claimed Tile (<__main__.Tile object at 0x7f0de036b730>,)
# Worker 11 claimed Tile (<__main__.Tile object at 0x7f0de03fc850>,)
# Worker 190 claimed Tile (<__main__.Tile object at 0x7f0de18690f0>,)
# Worker 21 claimed Tile (<__main__.Tile object at 0x7f0de01f23b0>,)
# Worker 24 claimed Tile (<__main__.Tile object at 0x7f0de01f2710>,)
# Worker 25 claimed Tile (<__main__.Tile object at 0x7f0de01f2380>,)
# Worker 26 claimed Tile (<__main__.Tile object at 0x7f0de01f05e0>,)
# Worker 27 claimed Tile (<__main__.Tile object at 0x7f0de186bd30>,)
# Worker 28 claimed Tile (<__main__.Tile object at 0x7f0de18697b0>,)
# Worker 29 claimed Tile (<__main__.Tile object at 0x7f0de1799030>,)
# Worker 30 claimed Tile (<__main__.Tile object at 0x7f0de00ecb20>,)
# Worker 31 claimed Tile (<__main__.Tile object at 0x7f0de18690f0>,)
# Worker 32 claimed Tile (<__main__.Tile object at 0x7f0de01f1d80>,)
# Worker 33 claimed Tile (<__main__.Tile object at 0x7f0de01115d0>,)
# Worker 34 claimed Tile (<__main__.Tile object at 0x7f0de0218bb0>,)
# Worker 35 claimed Tile (<__main__.Tile object at 0x7f0de021ae00>,)
# Worker 36 claimed Tile (<__main__.Tile object at 0x7f0de01d09a0>,)
# Worker 37 claimed Tile (<__main__.Tile object at 0x7f0de01d3670>,)
# Worker 23 claimed Tile (<__main__.Tile object at 0x7f0de01d28c0>,)
# Worker 39 claimed Tile (<__main__.Tile object at 0x7f0de0391690>,)
# Worker 40 claimed Tile (<__main__.Tile object at 0x7f0de0390af0>,)
# Worker 41 claimed Tile (<__main__.Tile object at 0x7f0de0393df0>,)
# Worker 42 claimed Tile (<__main__.Tile object at 0x7f0de01d16c0>,)
# Worker 43 claimed Tile (<__main__.Tile object at 0x7f0de01ae0e0>,)
# Worker 44 claimed Tile (<__main__.Tile object at 0x7f0de01af4f0>,)
# Worker 45 claimed Tile (<__main__.Tile object at 0x7f0de01af340>,)
# Worker 46 claimed Tile (<__main__.Tile object at 0x7f0de01d2050>,)
# Worker 47 claimed Tile (<__main__.Tile object at 0x7f0de01d07f0>,)
# Worker 48 claimed Tile (<__main__.Tile object at 0x7f0de01d3670>,)
# Worker 49 claimed Tile (<__main__.Tile object at 0x7f0de02da530>,)
# Worker 50 claimed Tile (<__main__.Tile object at 0x7f0de02d97b0>,)
# Worker 51 claimed Tile (<__main__.Tile object at 0x7f0de02da290>,)
# Worker 52 claimed Tile (<__main__.Tile object at 0x7f0de02b1b10>,)
# Worker 53 claimed Tile (<__main__.Tile object at 0x7f0de02b3100>,)
# Worker 54 claimed Tile (<__main__.Tile object at 0x7f0de02b10c0>,)
# Worker 16 claimed Tile (<__main__.Tile object at 0x7f0de02d9d80>,)
# Worker 56 claimed Tile (<__main__.Tile object at 0x7f0de02da290>,)
# Worker 57 claimed Tile (<__main__.Tile object at 0x7f0de02b3a60>,)
# Worker 58 claimed Tile (<__main__.Tile object at 0x7f0de02b0580>,)
# Worker 59 claimed Tile (<__main__.Tile object at 0x7f0de043dff0>,)
# Worker 60 claimed Tile (<__main__.Tile object at 0x7f0de043e590>,)
# Worker 61 claimed Tile (<__main__.Tile object at 0x7f0de043d690>,)
# Worker 62 claimed Tile (<__main__.Tile object at 0x7f0de043e590>,)
# Worker 63 claimed Tile (<__main__.Tile object at 0x7f0de042bf70>,)
# Worker 64 claimed Tile (<__main__.Tile object at 0x7f0de0429150>,)
# Worker 65 claimed Tile (<__main__.Tile object at 0x7f0de0492ec0>,)
# Worker 66 claimed Tile (<__main__.Tile object at 0x7f0de0429600>,)
# Worker 67 claimed Tile (<__main__.Tile object at 0x7f0de04288b0>,)
# Worker 68 claimed Tile (<__main__.Tile object at 0x7f0de042a890>,)
# Worker 69 claimed Tile (<__main__.Tile object at 0x7f0de0428040>,)
# Worker 70 claimed Tile (<__main__.Tile object at 0x7f0de042a890>,)
# Worker 71 claimed Tile (<__main__.Tile object at 0x7f0de03d09d0>,)
# Worker 72 claimed Tile (<__main__.Tile object at 0x7f0de0584e20>,)
# Worker 73 claimed Tile (<__main__.Tile object at 0x7f0de0586d70>,)
# Worker 74 claimed Tile (<__main__.Tile object at 0x7f0de05601c0>,)
# Worker 75 claimed Tile (<__main__.Tile object at 0x7f0de0562a40>,)
# Worker 76 claimed Tile (<__main__.Tile object at 0x7f0de05615a0>,)
# Worker 77 claimed Tile (<__main__.Tile object at 0x7f0de16158d0>,)
# Worker 78 claimed Tile (<__main__.Tile object at 0x7f0de0560910>,)
# Worker 79 claimed Tile (<__main__.Tile object at 0x7f0de16163b0>,)
# Worker 80 claimed Tile (<__main__.Tile object at 0x7f0de05614b0>,)
# Worker 81 claimed Tile (<__main__.Tile object at 0x7f0de0560250>,)
# Worker 82 claimed Tile (<__main__.Tile object at 0x7f0de0562050>,)
# Worker 83 claimed Tile (<__main__.Tile object at 0x7f0de0562200>,)
# Worker 84 claimed Tile (<__main__.Tile object at 0x7f0de012cf70>,)
# Worker 85 claimed Tile (<__main__.Tile object at 0x7f0de012e410>,)
# Worker 86 claimed Tile (<__main__.Tile object at 0x7f0de012dc30>,)
# Worker 87 claimed Tile (<__main__.Tile object at 0x7f0de012f1c0>,)
# Worker 88 claimed Tile (<__main__.Tile object at 0x7f0de012e950>,)
# Worker 89 claimed Tile (<__main__.Tile object at 0x7f0de012f520>,)
# Worker 90 claimed Tile (<__main__.Tile object at 0x7f0de012eef0>,)
# Worker 91 claimed Tile (<__main__.Tile object at 0x7f0de00fd960>,)
# Worker 92 claimed Tile (<__main__.Tile object at 0x7f0de00fd6f0>,)
# Worker 93 claimed Tile (<__main__.Tile object at 0x7f0de00fe170>,)
# Worker 94 claimed Tile (<__main__.Tile object at 0x7f0de00fe620>,)
# Worker 95 claimed Tile (<__main__.Tile object at 0x7f0de00ffd90>,)
# Worker 96 claimed Tile (<__main__.Tile object at 0x7f0de00fe170>,)
# Worker 97 claimed Tile (<__main__.Tile object at 0x7f0de018e140>,)
# Worker 98 claimed Tile (<__main__.Tile object at 0x7f0de018c880>,)
# Worker 99 claimed Tile (<__main__.Tile object at 0x7f0de018c3a0>,)
# Worker 100 claimed Tile (<__main__.Tile object at 0x7f0de018f7f0>,)
# Worker 101 claimed Tile (<__main__.Tile object at 0x7f0de018c9d0>,)
# Worker 102 claimed Tile (<__main__.Tile object at 0x7f0de018d0f0>,)
# Worker 103 claimed Tile (<__main__.Tile object at 0x7f0de01fd030>,)
# Worker 104 claimed Tile (<__main__.Tile object at 0x7f0de01fd810>,)
# Worker 105 claimed Tile (<__main__.Tile object at 0x7f0de01fc490>,)
# Worker 106 claimed Tile (<__main__.Tile object at 0x7f0de01ff9a0>,)
# Worker 107 claimed Tile (<__main__.Tile object at 0x7f0de01fd630>,)
# Worker 108 claimed Tile (<__main__.Tile object at 0x7f0de01fcac0>,)
# Worker 109 claimed Tile (<__main__.Tile object at 0x7f0de01fd030>,)
# Worker 110 claimed Tile (<__main__.Tile object at 0x7f0de01fdb70>,)
# Worker 111 claimed Tile (<__main__.Tile object at 0x7f0de01fc3a0>,)
# Worker 112 claimed Tile (<__main__.Tile object at 0x7f0de01ff040>,)
# Worker 114 claimed Tile (<__main__.Tile object at 0x7f0de018d540>,)
# Worker 113 claimed Tile (<__main__.Tile object at 0x7f0de018f880>,)
# Worker 115 claimed Tile (<__main__.Tile object at 0x7f0de018ec50>,)
# Worker 116 claimed Tile (<__main__.Tile object at 0x7f0de018c880>,)
# Worker 117 claimed Tile (<__main__.Tile object at 0x7f0de01fdc90>,)
# Worker 118 claimed Tile (<__main__.Tile object at 0x7f0de01fd870>,)
# Worker 119 claimed Tile (<__main__.Tile object at 0x7f0de01ff9a0>,)
# Worker 120 claimed Tile (<__main__.Tile object at 0x7f0de0284700>,)
# Worker 121 claimed Tile (<__main__.Tile object at 0x7f0de0286500>,)
# Worker 122 claimed Tile (<__main__.Tile object at 0x7f0de0284cd0>,)
# Worker 123 claimed Tile (<__main__.Tile object at 0x7f0de02655a0>,)
# Worker 124 claimed Tile (<__main__.Tile object at 0x7f0de0265d20>,)
# Worker 125 claimed Tile (<__main__.Tile object at 0x7f0de0266470>,)
# Worker 126 claimed Tile (<__main__.Tile object at 0x7f0de0264dc0>,)
# Worker 127 claimed Tile (<__main__.Tile object at 0x7f0de0267a00>,)
# Worker 128 claimed Tile (<__main__.Tile object at 0x7f0de0267550>,)
# Worker 129 claimed Tile (<__main__.Tile object at 0x7f0de0284bb0>,)
# Worker 130 claimed Tile (<__main__.Tile object at 0x7f0de0284af0>,)
# Worker 131 claimed Tile (<__main__.Tile object at 0x7f0de01fdc90>,)
# Worker 132 claimed Tile (<__main__.Tile object at 0x7f0de01fcfa0>,)
# Worker 20 claimed Tile (<__main__.Tile object at 0x7f0de01ffb50>,)
# Worker 134 claimed Tile (<__main__.Tile object at 0x7f0de018c3a0>,)
# Worker 135 claimed Tile (<__main__.Tile object at 0x7f0de01fca60>,)
# Worker 136 claimed Tile (<__main__.Tile object at 0x7f0de01fe980>,)
# Worker 3 claimed Tile (<__main__.Tile object at 0x7f0de01fcfa0>,)
# Worker 138 claimed Tile (<__main__.Tile object at 0x7f0de01ff940>,)
# Worker 139 claimed Tile (<__main__.Tile object at 0x7f0de01aca30>,)
# Worker 140 claimed Tile (<__main__.Tile object at 0x7f0de01ada50>,)
# Worker 141 claimed Tile (<__main__.Tile object at 0x7f0de01ac100>,)
# Worker 142 claimed Tile (<__main__.Tile object at 0x7f0de0391210>,)
# Worker 143 claimed Tile (<__main__.Tile object at 0x7f0de03929e0>,)
# Worker 144 claimed Tile (<__main__.Tile object at 0x7f0de03912a0>,)
# Worker 145 claimed Tile (<__main__.Tile object at 0x7f0de036af80>,)
# Worker 146 claimed Tile (<__main__.Tile object at 0x7f0de036a920>,)
# Worker 147 claimed Tile (<__main__.Tile object at 0x7f0de0368070>,)
# Worker 148 claimed Tile (<__main__.Tile object at 0x7f0de036a5f0>,)
# Worker 149 claimed Tile (<__main__.Tile object at 0x7f0de036ba60>,)
# Worker 150 claimed Tile (<__main__.Tile object at 0x7f0de03910c0>,)
# Worker 151 claimed Tile (<__main__.Tile object at 0x7f0de0391ab0>,)
# Worker 152 claimed Tile (<__main__.Tile object at 0x7f0de01aeb90>,)
# Worker 153 claimed Tile (<__main__.Tile object at 0x7f0de01ad9f0>,)
# Worker 154 claimed Tile (<__main__.Tile object at 0x7f0de01ae560>,)
# Worker 155 claimed Tile (<__main__.Tile object at 0x7f0de01ac340>,)
# Worker 156 claimed Tile (<__main__.Tile object at 0x7f0de01ac1c0>,)
# Worker 157 claimed Tile (<__main__.Tile object at 0x7f0de01ac160>,)
# Worker 158 claimed Tile (<__main__.Tile object at 0x7f0de0493340>,)
# Worker 159 claimed Tile (<__main__.Tile object at 0x7f0de01af280>,)
# Worker 160 claimed Tile (<__main__.Tile object at 0x7f0de01ad600>,)
# Worker 161 claimed Tile (<__main__.Tile object at 0x7f0de01ac580>,)
# Worker 162 claimed Tile (<__main__.Tile object at 0x7f0de01ac520>,)
# Worker 163 claimed Tile (<__main__.Tile object at 0x7f0de01fca60>,)
# Worker 164 claimed Tile (<__main__.Tile object at 0x7f0de01fd870>,)
# Worker 165 claimed Tile (<__main__.Tile object at 0x7f0de018f310>,)
# Worker 166 claimed Tile (<__main__.Tile object at 0x7f0de01af820>,)
# Worker 167 claimed Tile (<__main__.Tile object at 0x7f0de01ad420>,)
# Worker 168 claimed Tile (<__main__.Tile object at 0x7f0de03fef80>,)
# Worker 169 claimed Tile (<__main__.Tile object at 0x7f0de03fec20>,)
# Worker 170 claimed Tile (<__main__.Tile object at 0x7f0de01af190>,)
# Worker 171 claimed Tile (<__main__.Tile object at 0x7f0de01af910>,)
# Worker 172 claimed Tile (<__main__.Tile object at 0x7f0de018f7f0>,)
# Worker 173 claimed Tile (<__main__.Tile object at 0x7f0de018ffa0>,)
# Worker 174 claimed Tile (<__main__.Tile object at 0x7f0de018f8b0>,)
# Worker 175 claimed Tile (<__main__.Tile object at 0x7f0de018e080>,)
# Worker 176 claimed Tile (<__main__.Tile object at 0x7f0de00ff1f0>,)
# Worker 177 claimed Tile (<__main__.Tile object at 0x7f0de00fd5a0>,)
# Worker 178 claimed Tile (<__main__.Tile object at 0x7f0de00feb60>,)
# Worker 179 claimed Tile (<__main__.Tile object at 0x7f0de00fc880>,)
# Worker 180 claimed Tile (<__main__.Tile object at 0x7f0de00ff1f0>,)
# Worker 181 claimed Tile (<__main__.Tile object at 0x7f0de00fc880>,)
# Worker 182 claimed Tile (<__main__.Tile object at 0x7f0de05378b0>,)
# Worker 183 claimed Tile (<__main__.Tile object at 0x7f0de05379d0>,)
# Worker 184 claimed Tile (<__main__.Tile object at 0x7f0de0535b10>,)
# Worker 185 claimed Tile (<__main__.Tile object at 0x7f0de0536e30>,)
# Worker 186 claimed Tile (<__main__.Tile object at 0x7f0de1615d80>,)
# Worker 187 claimed Tile (<__main__.Tile object at 0x7f0de16177c0>,)
# Worker 188 claimed Tile (<__main__.Tile object at 0x7f0de1615ff0>,)
# Worker 189 claimed Tile (<__main__.Tile object at 0x7f0de16170d0>,)
# Worker 38 claimed Tile (<__main__.Tile object at 0x7f0de0537910>,)
# Worker 22 claimed Tile (<__main__.Tile object at 0x7f0de1615ff0>,)
# Worker 192 claimed Tile (<__main__.Tile object at 0x7f0de05378b0>,)
# Worker 193 claimed Tile (<__main__.Tile object at 0x7f0de1617af0>,)
# Worker 194 claimed Tile (<__main__.Tile object at 0x7f0de16147f0>,)
# Worker 195 claimed Tile (<__main__.Tile object at 0x7f0de1614820>,)
# Worker 196 claimed Tile (<__main__.Tile object at 0x7f0de00a8940>,)
# Worker 197 claimed Tile (<__main__.Tile object at 0x7f0de00a9120>,)
# Worker 198 claimed Tile (<__main__.Tile object at 0x7f0de00a8a00>,)
# Worker 199 claimed Tile (<__main__.Tile object at 0x7f0de00a9cf0>,)
# Worker 4 claimed Tile (<__main__.Tile object at 0x7f0de00a8940>,)
# Worker 137 claimed Tile (<__main__.Tile object at 0x7f0de00a8520>,)
# Worker 191 claimed Tile (<__main__.Tile object at 0x7f0de17ab370>,)
# Worker 2 claimed Tile (<__main__.Tile object at 0x7f0de17ab2e0>,)
# Worker 13 claimed Tile (<__main__.Tile object at 0x7f0de0391960>,)
# Worker 17 claimed Tile (<__main__.Tile object at 0x7f0de186a1a0>,)
# Worker 10 claimed Tile (<__main__.Tile object at 0x7f0de1868fa0>,)
# Worker 12 claimed Tile (<__main__.Tile object at 0x7f0de1868340>,)
# Worker 7 claimed Tile (<__main__.Tile object at 0x7f0de1869cc0>,)
# Worker 19 claimed Tile (<__main__.Tile object at 0x7f0de0265e10>,)
# Worker 8 claimed Tile (<__main__.Tile object at 0x7f0de00ca3b0>,)
# Worker 14 claimed Tile (<__main__.Tile object at 0x7f0de00c9450>,)
# Worker 6 claimed Tile (<__main__.Tile object at 0x7f0de00c8c40>,)
# Worker 5 claimed Tile (<__main__.Tile object at 0x7f0de00c91e0>,)
#
# Summary:
# Worker 1 claimed Tile (<__main__.Tile object at 0x7f0de02842e0>,)
# Worker 15 claimed Tile (<__main__.Tile object at 0x7f0de0391810>,)
# Worker 11 claimed Tile (<__main__.Tile object at 0x7f0de03fc850>,)
# Worker 55 claimed Tile (<__main__.Tile object at 0x7f0de03d3cd0>,)
# Worker 0 claimed Tile (<__main__.Tile object at 0x7f0de00c9750>,)
# Worker 9 claimed Tile (<__main__.Tile object at 0x7f0de00fc5b0>,)
# Worker 133 claimed Tile (<__main__.Tile object at 0x7f0de036b730>,)
# Worker 18 claimed Tile (<__main__.Tile object at 0x7f0de01dfd60>,)
# Worker 190 claimed Tile (<__main__.Tile object at 0x7f0de18690f0>,)
# Worker 21 claimed Tile (<__main__.Tile object at 0x7f0de01f23b0>,)
# Worker 24 claimed Tile (<__main__.Tile object at 0x7f0de01f2710>,)
# Worker 25 claimed Tile (<__main__.Tile object at 0x7f0de01f2380>,)
# Worker 26 claimed Tile (<__main__.Tile object at 0x7f0de01f05e0>,)
# Worker 27 claimed Tile (<__main__.Tile object at 0x7f0de186bd30>,)
# Worker 28 claimed Tile (<__main__.Tile object at 0x7f0de18697b0>,)
# Worker 29 claimed Tile (<__main__.Tile object at 0x7f0de1799030>,)
# Worker 30 claimed Tile (<__main__.Tile object at 0x7f0de00ecb20>,)
# Worker 31 claimed Tile (<__main__.Tile object at 0x7f0de18690f0>,)
# Worker 32 claimed Tile (<__main__.Tile object at 0x7f0de01f1d80>,)
# Worker 33 claimed Tile (<__main__.Tile object at 0x7f0de01115d0>,)
# Worker 34 claimed Tile (<__main__.Tile object at 0x7f0de0218bb0>,)
# Worker 35 claimed Tile (<__main__.Tile object at 0x7f0de021ae00>,)
# Worker 36 claimed Tile (<__main__.Tile object at 0x7f0de01d09a0>,)
# Worker 37 claimed Tile (<__main__.Tile object at 0x7f0de01d3670>,)
# Worker 23 claimed Tile (<__main__.Tile object at 0x7f0de01d28c0>,)
# Worker 39 claimed Tile (<__main__.Tile object at 0x7f0de0391690>,)
# Worker 40 claimed Tile (<__main__.Tile object at 0x7f0de0390af0>,)
# Worker 41 claimed Tile (<__main__.Tile object at 0x7f0de0393df0>,)
# Worker 42 claimed Tile (<__main__.Tile object at 0x7f0de01d16c0>,)
# Worker 43 claimed Tile (<__main__.Tile object at 0x7f0de01ae0e0>,)
# Worker 44 claimed Tile (<__main__.Tile object at 0x7f0de01af4f0>,)
# Worker 45 claimed Tile (<__main__.Tile object at 0x7f0de01af340>,)
# Worker 46 claimed Tile (<__main__.Tile object at 0x7f0de01d2050>,)
# Worker 47 claimed Tile (<__main__.Tile object at 0x7f0de01d07f0>,)
# Worker 48 claimed Tile (<__main__.Tile object at 0x7f0de01d3670>,)
# Worker 49 claimed Tile (<__main__.Tile object at 0x7f0de02da530>,)
# Worker 50 claimed Tile (<__main__.Tile object at 0x7f0de02d97b0>,)
# Worker 51 claimed Tile (<__main__.Tile object at 0x7f0de02da290>,)
# Worker 52 claimed Tile (<__main__.Tile object at 0x7f0de02b1b10>,)
# Worker 53 claimed Tile (<__main__.Tile object at 0x7f0de02b3100>,)
# Worker 54 claimed Tile (<__main__.Tile object at 0x7f0de02b10c0>,)
# Worker 16 claimed Tile (<__main__.Tile object at 0x7f0de02d9d80>,)
# Worker 56 claimed Tile (<__main__.Tile object at 0x7f0de02da290>,)
# Worker 57 claimed Tile (<__main__.Tile object at 0x7f0de02b3a60>,)
# Worker 58 claimed Tile (<__main__.Tile object at 0x7f0de02b0580>,)
# Worker 59 claimed Tile (<__main__.Tile object at 0x7f0de043dff0>,)
# Worker 60 claimed Tile (<__main__.Tile object at 0x7f0de043e590>,)
# Worker 61 claimed Tile (<__main__.Tile object at 0x7f0de043d690>,)
# Worker 62 claimed Tile (<__main__.Tile object at 0x7f0de043e590>,)
# Worker 63 claimed Tile (<__main__.Tile object at 0x7f0de042bf70>,)
# Worker 64 claimed Tile (<__main__.Tile object at 0x7f0de0429150>,)
# Worker 65 claimed Tile (<__main__.Tile object at 0x7f0de0492ec0>,)
# Worker 66 claimed Tile (<__main__.Tile object at 0x7f0de0429600>,)
# Worker 67 claimed Tile (<__main__.Tile object at 0x7f0de04288b0>,)
# Worker 68 claimed Tile (<__main__.Tile object at 0x7f0de042a890>,)
# Worker 69 claimed Tile (<__main__.Tile object at 0x7f0de0428040>,)
# Worker 70 claimed Tile (<__main__.Tile object at 0x7f0de042a890>,)
# Worker 71 claimed Tile (<__main__.Tile object at 0x7f0de03d09d0>,)
# Worker 72 claimed Tile (<__main__.Tile object at 0x7f0de0584e20>,)
# Worker 73 claimed Tile (<__main__.Tile object at 0x7f0de0586d70>,)
# Worker 74 claimed Tile (<__main__.Tile object at 0x7f0de05601c0>,)
# Worker 75 claimed Tile (<__main__.Tile object at 0x7f0de0562a40>,)
# Worker 76 claimed Tile (<__main__.Tile object at 0x7f0de05615a0>,)
# Worker 77 claimed Tile (<__main__.Tile object at 0x7f0de16158d0>,)
# Worker 78 claimed Tile (<__main__.Tile object at 0x7f0de0560910>,)
# Worker 79 claimed Tile (<__main__.Tile object at 0x7f0de16163b0>,)
# Worker 80 claimed Tile (<__main__.Tile object at 0x7f0de05614b0>,)
# Worker 81 claimed Tile (<__main__.Tile object at 0x7f0de0560250>,)
# Worker 82 claimed Tile (<__main__.Tile object at 0x7f0de0562050>,)
# Worker 83 claimed Tile (<__main__.Tile object at 0x7f0de0562200>,)
# Worker 84 claimed Tile (<__main__.Tile object at 0x7f0de012cf70>,)
# Worker 85 claimed Tile (<__main__.Tile object at 0x7f0de012e410>,)
# Worker 86 claimed Tile (<__main__.Tile object at 0x7f0de012dc30>,)
# Worker 87 claimed Tile (<__main__.Tile object at 0x7f0de012f1c0>,)
# Worker 88 claimed Tile (<__main__.Tile object at 0x7f0de012e950>,)
# Worker 89 claimed Tile (<__main__.Tile object at 0x7f0de012f520>,)
# Worker 90 claimed Tile (<__main__.Tile object at 0x7f0de012eef0>,)
# Worker 91 claimed Tile (<__main__.Tile object at 0x7f0de00fd960>,)
# Worker 92 claimed Tile (<__main__.Tile object at 0x7f0de00fd6f0>,)
# Worker 93 claimed Tile (<__main__.Tile object at 0x7f0de00fe170>,)
# Worker 94 claimed Tile (<__main__.Tile object at 0x7f0de00fe620>,)
# Worker 95 claimed Tile (<__main__.Tile object at 0x7f0de00ffd90>,)
# Worker 96 claimed Tile (<__main__.Tile object at 0x7f0de00fe170>,)
# Worker 97 claimed Tile (<__main__.Tile object at 0x7f0de018e140>,)
# Worker 98 claimed Tile (<__main__.Tile object at 0x7f0de018c880>,)
# Worker 99 claimed Tile (<__main__.Tile object at 0x7f0de018c3a0>,)
# Worker 100 claimed Tile (<__main__.Tile object at 0x7f0de018f7f0>,)
# Worker 101 claimed Tile (<__main__.Tile object at 0x7f0de018c9d0>,)
# Worker 102 claimed Tile (<__main__.Tile object at 0x7f0de018d0f0>,)
# Worker 103 claimed Tile (<__main__.Tile object at 0x7f0de01fd030>,)
# Worker 104 claimed Tile (<__main__.Tile object at 0x7f0de01fd810>,)
# Worker 105 claimed Tile (<__main__.Tile object at 0x7f0de01fc490>,)
# Worker 106 claimed Tile (<__main__.Tile object at 0x7f0de01ff9a0>,)
# Worker 107 claimed Tile (<__main__.Tile object at 0x7f0de01fd630>,)
# Worker 108 claimed Tile (<__main__.Tile object at 0x7f0de01fcac0>,)
# Worker 109 claimed Tile (<__main__.Tile object at 0x7f0de01fd030>,)
# Worker 110 claimed Tile (<__main__.Tile object at 0x7f0de01fdb70>,)
# Worker 111 claimed Tile (<__main__.Tile object at 0x7f0de01fc3a0>,)
# Worker 112 claimed Tile (<__main__.Tile object at 0x7f0de01ff040>,)
# Worker 114 claimed Tile (<__main__.Tile object at 0x7f0de018d540>,)
# Worker 113 claimed Tile (<__main__.Tile object at 0x7f0de018f880>,)
# Worker 115 claimed Tile (<__main__.Tile object at 0x7f0de018ec50>,)
# Worker 116 claimed Tile (<__main__.Tile object at 0x7f0de018c880>,)
# Worker 117 claimed Tile (<__main__.Tile object at 0x7f0de01fdc90>,)
# Worker 118 claimed Tile (<__main__.Tile object at 0x7f0de01fd870>,)
# Worker 119 claimed Tile (<__main__.Tile object at 0x7f0de01ff9a0>,)
# Worker 120 claimed Tile (<__main__.Tile object at 0x7f0de0284700>,)
# Worker 121 claimed Tile (<__main__.Tile object at 0x7f0de0286500>,)
# Worker 122 claimed Tile (<__main__.Tile object at 0x7f0de0284cd0>,)
# Worker 123 claimed Tile (<__main__.Tile object at 0x7f0de02655a0>,)
# Worker 124 claimed Tile (<__main__.Tile object at 0x7f0de0265d20>,)
# Worker 125 claimed Tile (<__main__.Tile object at 0x7f0de0266470>,)
# Worker 126 claimed Tile (<__main__.Tile object at 0x7f0de0264dc0>,)
# Worker 127 claimed Tile (<__main__.Tile object at 0x7f0de0267a00>,)
# Worker 128 claimed Tile (<__main__.Tile object at 0x7f0de0267550>,)
# Worker 129 claimed Tile (<__main__.Tile object at 0x7f0de0284bb0>,)
# Worker 130 claimed Tile (<__main__.Tile object at 0x7f0de0284af0>,)
# Worker 131 claimed Tile (<__main__.Tile object at 0x7f0de01fdc90>,)
# Worker 132 claimed Tile (<__main__.Tile object at 0x7f0de01fcfa0>,)
# Worker 20 claimed Tile (<__main__.Tile object at 0x7f0de01ffb50>,)
# Worker 134 claimed Tile (<__main__.Tile object at 0x7f0de018c3a0>,)
# Worker 135 claimed Tile (<__main__.Tile object at 0x7f0de01fca60>,)
# Worker 136 claimed Tile (<__main__.Tile object at 0x7f0de01fe980>,)
# Worker 3 claimed Tile (<__main__.Tile object at 0x7f0de01fcfa0>,)
# Worker 138 claimed Tile (<__main__.Tile object at 0x7f0de01ff940>,)
# Worker 139 claimed Tile (<__main__.Tile object at 0x7f0de01aca30>,)
# Worker 140 claimed Tile (<__main__.Tile object at 0x7f0de01ada50>,)
# Worker 141 claimed Tile (<__main__.Tile object at 0x7f0de01ac100>,)
# Worker 142 claimed Tile (<__main__.Tile object at 0x7f0de0391210>,)
# Worker 143 claimed Tile (<__main__.Tile object at 0x7f0de03929e0>,)
# Worker 144 claimed Tile (<__main__.Tile object at 0x7f0de03912a0>,)
# Worker 145 claimed Tile (<__main__.Tile object at 0x7f0de036af80>,)
# Worker 146 claimed Tile (<__main__.Tile object at 0x7f0de036a920>,)
# Worker 147 claimed Tile (<__main__.Tile object at 0x7f0de0368070>,)
# Worker 148 claimed Tile (<__main__.Tile object at 0x7f0de036a5f0>,)
# Worker 149 claimed Tile (<__main__.Tile object at 0x7f0de036ba60>,)
# Worker 150 claimed Tile (<__main__.Tile object at 0x7f0de03910c0>,)
# Worker 151 claimed Tile (<__main__.Tile object at 0x7f0de0391ab0>,)
# Worker 152 claimed Tile (<__main__.Tile object at 0x7f0de01aeb90>,)
# Worker 153 claimed Tile (<__main__.Tile object at 0x7f0de01ad9f0>,)
# Worker 154 claimed Tile (<__main__.Tile object at 0x7f0de01ae560>,)
# Worker 155 claimed Tile (<__main__.Tile object at 0x7f0de01ac340>,)
# Worker 156 claimed Tile (<__main__.Tile object at 0x7f0de01ac1c0>,)
# Worker 157 claimed Tile (<__main__.Tile object at 0x7f0de01ac160>,)
# Worker 158 claimed Tile (<__main__.Tile object at 0x7f0de0493340>,)
# Worker 159 claimed Tile (<__main__.Tile object at 0x7f0de01af280>,)
# Worker 160 claimed Tile (<__main__.Tile object at 0x7f0de01ad600>,)
# Worker 161 claimed Tile (<__main__.Tile object at 0x7f0de01ac580>,)
# Worker 162 claimed Tile (<__main__.Tile object at 0x7f0de01ac520>,)
# Worker 163 claimed Tile (<__main__.Tile object at 0x7f0de01fca60>,)
# Worker 164 claimed Tile (<__main__.Tile object at 0x7f0de01fd870>,)
# Worker 165 claimed Tile (<__main__.Tile object at 0x7f0de018f310>,)
# Worker 166 claimed Tile (<__main__.Tile object at 0x7f0de01af820>,)
# Worker 167 claimed Tile (<__main__.Tile object at 0x7f0de01ad420>,)
# Worker 168 claimed Tile (<__main__.Tile object at 0x7f0de03fef80>,)
# Worker 169 claimed Tile (<__main__.Tile object at 0x7f0de03fec20>,)
# Worker 170 claimed Tile (<__main__.Tile object at 0x7f0de01af190>,)
# Worker 171 claimed Tile (<__main__.Tile object at 0x7f0de01af910>,)
# Worker 172 claimed Tile (<__main__.Tile object at 0x7f0de018f7f0>,)
# Worker 173 claimed Tile (<__main__.Tile object at 0x7f0de018ffa0>,)
# Worker 174 claimed Tile (<__main__.Tile object at 0x7f0de018f8b0>,)
# Worker 175 claimed Tile (<__main__.Tile object at 0x7f0de018e080>,)
# Worker 176 claimed Tile (<__main__.Tile object at 0x7f0de00ff1f0>,)
# Worker 177 claimed Tile (<__main__.Tile object at 0x7f0de00fd5a0>,)
# Worker 178 claimed Tile (<__main__.Tile object at 0x7f0de00feb60>,)
# Worker 179 claimed Tile (<__main__.Tile object at 0x7f0de00fc880>,)
# Worker 180 claimed Tile (<__main__.Tile object at 0x7f0de00ff1f0>,)
# Worker 181 claimed Tile (<__main__.Tile object at 0x7f0de00fc880>,)
# Worker 182 claimed Tile (<__main__.Tile object at 0x7f0de05378b0>,)
# Worker 183 claimed Tile (<__main__.Tile object at 0x7f0de05379d0>,)
# Worker 184 claimed Tile (<__main__.Tile object at 0x7f0de0535b10>,)
# Worker 185 claimed Tile (<__main__.Tile object at 0x7f0de0536e30>,)
# Worker 186 claimed Tile (<__main__.Tile object at 0x7f0de1615d80>,)
# Worker 187 claimed Tile (<__main__.Tile object at 0x7f0de16177c0>,)
# Worker 188 claimed Tile (<__main__.Tile object at 0x7f0de1615ff0>,)
# Worker 189 claimed Tile (<__main__.Tile object at 0x7f0de16170d0>,)
# Worker 38 claimed Tile (<__main__.Tile object at 0x7f0de0537910>,)
# Worker 22 claimed Tile (<__main__.Tile object at 0x7f0de1615ff0>,)
# Worker 192 claimed Tile (<__main__.Tile object at 0x7f0de05378b0>,)
# Worker 193 claimed Tile (<__main__.Tile object at 0x7f0de1617af0>,)
# Worker 194 claimed Tile (<__main__.Tile object at 0x7f0de16147f0>,)
# Worker 195 claimed Tile (<__main__.Tile object at 0x7f0de1614820>,)
# Worker 196 claimed Tile (<__main__.Tile object at 0x7f0de00a8940>,)
# Worker 197 claimed Tile (<__main__.Tile object at 0x7f0de00a9120>,)
# Worker 198 claimed Tile (<__main__.Tile object at 0x7f0de00a8a00>,)
# Worker 199 claimed Tile (<__main__.Tile object at 0x7f0de00a9cf0>,)
# Worker 4 claimed Tile (<__main__.Tile object at 0x7f0de00a8940>,)
# Worker 137 claimed Tile (<__main__.Tile object at 0x7f0de00a8520>,)
# Worker 191 claimed Tile (<__main__.Tile object at 0x7f0de17ab370>,)
# Worker 2 claimed Tile (<__main__.Tile object at 0x7f0de17ab2e0>,)
# Worker 13 claimed Tile (<__main__.Tile object at 0x7f0de0391960>,)
# Worker 17 claimed Tile (<__main__.Tile object at 0x7f0de186a1a0>,)
# Worker 10 claimed Tile (<__main__.Tile object at 0x7f0de1868fa0>,)
# Worker 12 claimed Tile (<__main__.Tile object at 0x7f0de1868340>,)
# Worker 7 claimed Tile (<__main__.Tile object at 0x7f0de1869cc0>,)
# Worker 19 claimed Tile (<__main__.Tile object at 0x7f0de0265e10>,)
# Worker 8 claimed Tile (<__main__.Tile object at 0x7f0de00ca3b0>,)
# Worker 14 claimed Tile (<__main__.Tile object at 0x7f0de00c9450>,)
# Worker 6 claimed Tile (<__main__.Tile object at 0x7f0de00c8c40>,)
# Worker 5 claimed Tile (<__main__.Tile object at 0x7f0de00c91e0>,)
#
# Total claimed tiles: 200

# %%
result = getWorkersTile(-1)

# %%
result
