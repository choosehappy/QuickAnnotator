# %%
from quickannotator.db.crud.annotation import AnnotationStore, table_exists, build_annotation_table_name

image_id = 145  # Example image ID
annotation_class_id = 4  # Example annotation class ID
is_gt = True  # Example ground truth flag
in_work_mag = False  # Example in-work magnification
simplify_tolerance = 0.0  # Example simplify tolerance

# %%
# %%time
AnnotationStore(image_id, annotation_class_id, is_gt, in_work_mag=in_work_mag, simplify_tolerance=simplify_tolerance)
# Out:
# CPU times: user 3.23 ms, sys: 0 ns, total: 3.23 ms
# Wall time: 3.07 ms
# /opt/QuickAnnotator/quickannotator/db/crud/annotation.py:414: SAWarning: This declarative base already contains a class with the same class name and module name as quickannotator.db.crud.annotation.DynamicAnnotation, and will be replaced in the string-lookup table.
#   class DynamicAnnotation(base):

# %%
# %%time
table_exists(build_annotation_table_name(image_id, 6, is_gt))
# Out:
# CPU times: user 860 µs, sys: 744 µs, total: 1.6 ms
# Wall time: 1.36 ms
# False
